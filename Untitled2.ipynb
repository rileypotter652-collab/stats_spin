# %%
import random
fund = 0
odds = [1,2,3]
for part in range(1,1000):
    num = random.choice(odds)
    if(num == 1):
        fund = fund
    if(num == 2):
        fund = fund - 5
    if(num == 3):
        fund = fund + 5
print(fund)
# Out:
# 0
